# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
ratio_oof_path1 = 'run_lgb_20240730_145315'
ratio_oof_path2 = 'run_lgb_20240730_145329'

# %%
label = 'ratio of preparation/free drug'

# %%
train = pd.read_csv('./input/train.csv')
ratio_oof1 = pd.read_csv(f'./output/{ratio_oof_path1}/oof.csv')
ratio_oof2 = pd.read_csv(f'./output/{ratio_oof_path2}/oof.csv')

# %%
ratio_train1 = train.loc[(~train[label].isna())&(train['onehot_type of the preparation_free drug']!=1)&(train[label]>=0.1)].reset_index(drop=True)
ratio_train1['ori_ratio'] = ratio_train1[label]
ratio_train1[label] = np.log10(ratio_train1[label].apply(lambda x:max(x,1e-6)))
ratio_train1['error'] = (ratio_oof1[label].rank()-ratio_train1[label].rank()).abs()
ns = ratio_train1.loc[ratio_train1['error']>200,'number'].unique()
ratio_train2 = ratio_train1.loc[(~ratio_train1['number'].isin(ns))&((ratio_train1[label]>=np.log10(0.5))&(ratio_train1[label]<=np.log10(100)))].drop(['error'],axis=1).reset_index(drop=True)

# %%
numerical_cols = ['PEGylation or not','PEGylation ratio','p-gp inhibition?','size （nm）','PDI','zeta potantial（mV）','encapsulation efficiency（%）',' DL（g/g）',\
                  'target ligand density（mol，%）','target ligand density（number per nanoparticle）',]
onehot_cols = ['type of the preparation','surface coating','type of targeting ligand','targeting ligand','transport mechanism','type of receptor/transporter','name of receptor/transporter','p-gp inhibitor','animal model','administration route',\
               'laser/magnectic field/radiation','core composition of the preparation']

# %%
onehot_train_cols = {}
for onehot_col in onehot_cols:
    onehot_train_cols[onehot_col] = [col for col in ratio_train2.columns if f'onehot_{onehot_col}' in col]

# %%
numerical_col_num = len(numerical_cols)
onehot_col_num = 0
for onehot_col in onehot_cols:
    onehot_col_num += len([col for col in ratio_train2.columns if f'onehot_{onehot_col}' in col])

# %%
numerical_col_num+onehot_col_num
# Out:
# 526

# %%
feature_values = {}
for col in numerical_cols:
    if col in ['PEGylation or not','PEGylation ratio','size （nm）','target ligand density（mol，%）']:
        vs = ratio_train2[col].dropna().unique().tolist() 
        if col == 'PEGylation ratio':
            vs = [v for v in vs if v >=0 and v <= 55]
        if col == 'target ligand density（mol，%）':
            vs = [v for v in vs if v >=0.3 and v <= 34]
    elif col in ['p-gp inhibition?','encapsulation efficiency（%）',' DL（g/g）','target ligand density（number per nanoparticle）']:
        vs = [np.nan]
    else:
        vs = ratio_train2[col].unique().tolist()
    if col in ['size （nm）']:
        vs = [80,93,131,168,205,250]#list(set([v//20.*20 for v in vs]))
    elif col in ['PDI']:
        vs = [0.1,0.1547,0.2166,0.2785,0.3]#list(set([v//0.05*0.05 for v in vs]))
    elif col in ['zeta potantial（mV）']:
        vs = list(set([v//10.*10 for v in vs]))
        vs = [v for v in vs if not np.isnan(v)]
    feature_values[col] = vs
    
core = {'liposome':['cholesterol',
#  'dmpc',
 'spc',
#  'pc',
 'dotap',
#  'dope',
 'dspe-peg',
 'epc',
#  'bovine serum albumin',
#  'cholestrol',
#  'lecithin',
 'dspe-peg2000',
 'dspc',
 'dppc',
 'dopc',
#  'others',
 'dspe'],#['cholesterol', 'spc', 'pc', 'dspe-peg2000', 'others', 'dspe'],
       'nanoparticles':['plga',
 'spc',
 'au',
 'peg-pla',
 'chitosan',
 'dspe-peg',
 'epc',
 'bovine serum albumin',
 'hspc',
 'stearic acid',
 'peg-plga',
 'mpeg-pcl',
 'glyceryl monostearate',
 'pamam',
 'dspe',
 'peg-pamam',
 'ps',
 'phospholpon 90g',
 'nicotinamide',
 'cetyl palmitate',
 'tristearin',
 'n-butyl-cyanoacrylate',
 'plga-peg']}

targeting_ligand = {'antibody': ['ox26', 'item4 antibody'],
 'cell-penetrating peptide': ['gly-arg-lys-lys-arg-arg-gln-arg-arg-arg- gly (tat)',
  'mastoparan',
  'cell-penetrating peptide tat',
  'cereport (rmp-7)-pegdspe',
  'penetratin',
  'cpps-tat'],
 'folic acid': ['folic acid', 'none'],
 'non-antibody protein': ['transferrin+folic acid',
  'transferrin',
  'lactoferrin'],
 'others': ['β-hydroxybutyric acid',
  'phenylalanine',
  'phosphatidic acid (pa)',
  'ascorbic acid',
  'phosphatidylserine (ps)',
  'dehydroascorbic acid',
  'n-palmitoylglucosamine (npg)',
  'angiopep-2',
  'lactoferrin'],
 'peptide': ['lactofferin',
  'lmwp',
  'a dual receptor recognizing cell penetrating peptiderrrrrrrrdgr (r8dgr, lower case letter representsd-amino acid residue)',
  'amyloid beta',
  'angiopep-2\r\n',
  'penetrating peptide, rgd',
  'pep-1 (cgemgwvrc) peptide',
  'arg-ala-asp (rad)',
  'arg-gly-asp (rgd)',
  'r6dgr',
  'rgd',
  'scrambled peptide (hwpyahpthpsw)',
  'solanum\ntuberosum lectin',
  'crgd',
  'srgd',
  'csspiqgswtwengk(c)wtwgiirleq',
  't7 (haiyprh) peptide',
  't7 (haiyprh) peptide, tat (aygrkkrrqrrr) peptide',
  't7 序列： chaiyprh',
  'tat (aygrkkrrqrrr) peptide',
  'tgnykalhphngc',
  'tgnykalhphngc, qshyrhispaqvc',
  'egfr-targeting peptide (yhwygytpqnvi)',
  'transferrin receptor (tfr) aptamer',
  'glutathione ',
  '细胞穿透肽tat (aygrkkrrqrrr)',
  'i6p7',
  'i6p7scr',
  'internalizing tumor-penetrating peptide, irgd',
  'lactoferrin']}


for col in onehot_cols:
    if col == 'type of the preparation':
        feature_values[col] = ['liposome','nanoparticles']
    if col == 'type of targeting ligand':
        feature_values[col] = ['antibody','cell-penetrating peptide','folic acid','non-antibody protein','others','peptide']
    if col in ['surface coating','targeting ligand','transport mechanism','transport mechanism','type of receptor/transporter','name of receptor/transporter','p-gp inhibitor','laser/magnectic field/radiation']:
        feature_values[col] = [np.nan]
    if col == 'animal model':
        feature_values[col] = ['normal','brain tumor']
    if col == 'administration route':
        feature_values[col] = ['i.v.']

# %% [markdown]
# # Your designed parameters

# %%
feature_values['PEGylation or not'] = [1]*6
feature_values['PEGylation ratio'] = [2,3,3,3,3,2]
feature_values['size （nm）'] = [122.2,114,100.3,131,152,114.7]
feature_values['PDI'] = [0.315,0.204,0.248,0.225,0.243,0.253]
feature_values['zeta potantial（mV）'] = [-15,-3.74,-20.2,10,18.4,-21.9]
feature_values['target ligand density（mol，%）'] = [2,3,3,3,3,2]
feature_values['type of the preparation'] = ['nanoparticle']*6
feature_values['core composition of the preparation'] = ['plga']*6
feature_values['type of targeting ligand'] = ['peptide']*5+['non-antibody protein']
feature_values['targeting ligand'] = ['angiopep-2','t7 (haiyprh) peptide','tat','tat','tat','transferrin']
feature_values['animal model'] = ['normal']*6
feature_values['administration route'] = ['i.v.']*6

# %%
all_features = []
features = {}
i = 0
part = 0
for feature in feature_values.keys():
    try:
        if np.isnan(feature_values[feature][0]):
            if feature not in onehot_cols:
                features[feature] = np.nan
            else:
                for col in onehot_train_cols[feature]:
                    features[col] = np.nan
    except:
        pass

# %%
for i in range(len(feature_values['PEGylation or not'])):
    features['PEGylation or not'] = feature_values['PEGylation or not'][i]
    features['PEGylation ratio'] = feature_values['PEGylation ratio'][i]
    features['size （nm）'] = feature_values['size （nm）'][i]
    features['PDI'] = feature_values['PDI'][i]
    features['zeta potantial（mV）'] = feature_values['zeta potantial（mV）'][i]
    features['target ligand density（mol，%）'] = feature_values['target ligand density（mol，%）'][i]
    for f in ['type of the preparation','core composition of the preparation','type of targeting ligand','targeting ligand','animal model','administration route']:
        for col in onehot_train_cols[f]:
            print(col)
            if col.split('_')[-1] in feature_values[f][i].split(','):
                features[col] = 1
            else:
                features[col] = 0 
    all_features.append(features.copy())
# Out:
# onehot_type of the preparation_dendrimer
# onehot_type of the preparation_emulsion
# onehot_type of the preparation_extracellular vesicles
# onehot_type of the preparation_free drug
# onehot_type of the preparation_liposome
# onehot_type of the preparation_micelle
# onehot_type of the preparation_nanoparticles
# onehot_type of the preparation_none
# onehot_type of the preparation_others
# onehot_core composition of the preparation_plga
# onehot_core composition of the preparation_cholesterol
# onehot_core composition of the preparation_spc
# onehot_core composition of the preparation_au
# onehot_core composition of the preparation_pc
# onehot_core composition of the preparation_peg-pla
# onehot_core composition of the preparation_chitosan
# onehot_core composition of the preparation_dotap
# onehot_core composition of the preparation_dspe-peg
# onehot_core composition of the preparation_dope
# onehot_core composition of the preparation_epc
# onehot_core composition of the preparation_bovine serum albumin
# onehot_core composition of the preparation_spion
# onehot_core composition of the preparation_hspc
# onehot_core composition of the preparation_peg2000-dspe
# onehot_core composition of the preparation_dspe-peg2000
# onehot_core composition of the preparation_stearic acid
# onehot_core composition of the preparation_peg
# onehot_core composition of the preparation_pei
# onehot_core composition of the preparation_peg-plga
# onehot_core composition of the preparation_dspc
# onehot_core composition of the preparation_dppc
# onehot_core composition of the preparation_mpeg-pla
# onehot_core composition of the preparation_mpeg-pcl
# onehot_core composition of the preparation_dopc
# onehot_core composition of the preparation_glyceryl monostearate
# onehot_core composition of the preparation_mpeg2000-dspe
# onehot_core composition of the preparation_pamam
# onehot_core composition of the preparation_mpeg-pla2000
# onehot_core composition of the preparation_pva
# onehot_core composition of the preparation_peg-pcl
# onehot_core composition of the preparation_dspe
# onehot_core composition of the preparation_haucl4
# onehot_core composition of the preparation_cucl2
# onehot_core composition of the preparation_sio2
# onehot_core composition of the preparation_catechin hydrate
# onehot_core composition of the preparation_ps
# onehot_core composition of the preparation_dmpc
# onehot_core composition of the preparation_cetyl palmitate
# onehot_core composition of the preparation_nicotinamide
# onehot_core composition of the preparation_phospholpon 90g
# onehot_core composition of the preparation_male-peg-pla
# onehot_core composition of the preparation_peg-pamam
# onehot_core composition of the preparation_labrasol
# onehot_core composition of the preparation_cholestrol
# onehot_core composition of the preparation_tristearin
# onehot_core composition of the preparation_pla
# onehot_core composition of the preparation_n-butyl-cyanoacrylate
# onehot_core composition of the preparation_mal-peg-pla
# onehot_core composition of the preparation_lecithin
# onehot_core composition of the preparation_ir-775chloride(ir)
# onehot_core composition of the preparation_nppe
# onehot_core composition of the preparation_mc-peg3400-dspe
# onehot_core composition of the preparation_lipoid s75
# onehot_core composition of the preparation_fluorescent carboxylated-polystyrene
# onehot_core composition of the preparation_glycerol
# onehot_core composition of the preparation_plga-peg
# onehot_core composition of the preparation_glycerol monostearate
# onehot_core composition of the preparation_sodium stearate
# onehot_core composition of the preparation_pva9000
# onehot_core composition of the preparation_none
# onehot_core composition of the preparation_others
# onehot_type of targeting ligand_antibody
# onehot_type of targeting ligand_aptamer
# onehot_type of targeting ligand_cell-penetrating peptide
# onehot_type of targeting ligand_cell-penetrating peptide+transferrin
# onehot_type of targeting ligand_folic acid
# onehot_type of targeting ligand_glycosol
# onehot_type of targeting ligand_non-antibody protein
# onehot_type of targeting ligand_none
# onehot_type of targeting ligand_others
# onehot_type of targeting ligand_peptide
# onehot_type of targeting ligand_peptide and others
# onehot_targeting ligand_ lactoferrin
# onehot_targeting ligand_ n-acetyl pro–gly–pro (pgp)
# onehot_targeting ligand_ pep-1 (cgemgwvrc)
# onehot_targeting ligand_ r9f2
# onehot_targeting ligand_ r9f2+transferrin
# onehot_targeting ligand_ rabies virus glycoprotein (rvg) derivative
# onehot_targeting ligand_ tgn peptide (tgnykalhphng)
# onehot_targeting ligand_(tat)glyarglyslysargargglnargarg- argcysgly
# onehot_targeting ligand_15-amino acid peptide gyrpvhnirghwapg (gyr peptide)
# onehot_targeting ligand_8d3
# onehot_targeting ligand_a dual receptor recognizing cell penetrating peptiderrrrrrrrdgr (r8dgr, lower case letter representsd-amino acid residue)
# onehot_targeting ligand_acetylcholine,choline
# onehot_targeting ligand_acid-cleavable folic and kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_adenosine-based agonists
# onehot_targeting ligand_adipose-derived stem cells
# onehot_targeting ligand_amyloid beta
# onehot_targeting ligand_amyloid precursor protein
# onehot_targeting ligand_angiopep-2
# onehot_targeting ligand_angiopep-2
#
# onehot_targeting ligand_angiopep-2 (ang, tffyggsrgkrnnfkteey
# onehot_targeting ligand_angiopep-2 (tffyggsrgkrnnfkteeyc)
# onehot_targeting ligand_angiopep-2(tffyggsrgkrnnfkteeyc)
# onehot_targeting ligand_anti-nestin antibody
# onehot_targeting ligand_anti-nestin antibody，transferrin antibody
# onehot_targeting ligand_anti-pdgfrβ aptamer
# onehot_targeting ligand_anti-pirb antibody
# onehot_targeting ligand_anti-tfra
# onehot_targeting ligand_anti-tfra/bace1
# onehot_targeting ligand_anti-tfrd
# onehot_targeting ligand_anti-transferrin receptor antibody (8d3)-pegdspe
# onehot_targeting ligand_anti-vcam-1 antibody
# onehot_targeting ligand_ap1
# onehot_targeting ligand_apoe mimetic peptide
# onehot_targeting ligand_apolipopretoein e
# onehot_targeting ligand_aprotinin
# onehot_targeting ligand_arg-ala-asp (rad)
# onehot_targeting ligand_arg-gly-asp (rgd)
# onehot_targeting ligand_arg-gly-asp (rgd)+il-13
# onehot_targeting ligand_arginine–glycine–aspartic acid (rgd)
# onehot_targeting ligand_ascorbic acid
# onehot_targeting ligand_asn-gly-arg (ngr)
# onehot_targeting ligand_atwlppr
# onehot_targeting ligand_b6
# onehot_targeting ligand_b6+mazindol
# onehot_targeting ligand_bevacizumab
# onehot_targeting ligand_biotin
# onehot_targeting ligand_bombesin peptide (gqwavghlm)
# onehot_targeting ligand_borneol
# onehot_targeting ligand_bovine lf
# onehot_targeting ligand_c*nnskshtc*
# onehot_targeting ligand_cd 47
# onehot_targeting ligand_cdx peptide
# onehot_targeting ligand_cell-penetrating peptide tat
# onehot_targeting ligand_cereport (rmp-7)-pegdspe
# onehot_targeting ligand_cgcrk
# onehot_targeting ligand_cgkrk
# onehot_targeting ligand_cgkrk &  pep-1 (cgemgwvrc)
# onehot_targeting ligand_cgkrkgygatwllppr
# onehot_targeting ligand_chlorotoxin
# onehot_targeting ligand_cholera toxin b subunit
# onehot_targeting ligand_chondroitin sulfate
# onehot_targeting ligand_clpffd
# onehot_targeting ligand_cngr(cngrcg)
# onehot_targeting ligand_cpps-tat
# onehot_targeting ligand_creka
# onehot_targeting ligand_crgd
# onehot_targeting ligand_crgd(arg-gly-asp)
# onehot_targeting ligand_csspiqgswtwengk(c)wtwgiirleq
# onehot_targeting ligand_cvsrrrrrrggrrrr
# onehot_targeting ligand_cylic rgd
# onehot_targeting ligand_d cdx(greirtgraerwsekf)
# onehot_targeting ligand_d-ae
# onehot_targeting ligand_da7r (drdpdpdldwdtda)
# onehot_targeting ligand_dangiopep
# onehot_targeting ligand_dc(lyp-1)(cgnkrtrgc)
# onehot_targeting ligand_dc(lyp-1)+d cdx
# onehot_targeting ligand_dcdx, the retro–inverso isomer oflcdx,
# onehot_targeting ligand_dehydroascorbic acid
# onehot_targeting ligand_dspe-peg-rvg29 peptide
# onehot_targeting ligand_dspe-peg-triphenylphosphine (tpp)
# onehot_targeting ligand_dspe-peg-triphenylphosphine (tpp)+dspe-peg-rvg29 peptide
# onehot_targeting ligand_dspepeg-mannose
# onehot_targeting ligand_dspepeg-mannose/dspepeg-transferrin
# onehot_targeting ligand_dspepeg-transferrin
# onehot_targeting ligand_dvs (vswfsrhryspfavs)
# onehot_targeting ligand_edb-targeted peptide apt
# onehot_targeting ligand_egfp-egf1 (a protein derived from factor vii )
# onehot_targeting ligand_egfr-targeting peptide (yhwygytpqnvi)
# onehot_targeting ligand_fhk(fhkhkspalspv)
# onehot_targeting ligand_fibrin-binding peptide (creka)
# onehot_targeting ligand_folic
# onehot_targeting ligand_folic acid
# onehot_targeting ligand_folic acid (fa)
# onehot_targeting ligand_folic and kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_fucose
# derivative (l-type)
# onehot_targeting ligand_fucose
# derivative (r-type)
# onehot_targeting ligand_galactose derivative
# onehot_targeting ligand_glucose
# onehot_targeting ligand_glutathione
# onehot_targeting ligand_glutathione
# onehot_targeting ligand_gly-arg-lys-lys-arg-arg-gln-arg-arg-arg- gly (tat)
# onehot_targeting ligand_gly-l- phe-d-thr-gly-l-phe-l-leu-l-ser(o-β-d-glucose)- conh2.
# onehot_targeting ligand_h-thr(bzl)-phe-phe-tyr(br-z)-gly-gly-ser(bzl)-arg(tos)-gly-lys(cl-z)-arg(tos)-asn(xan)-asn(xan)-phe-lys(cl-z)-thr(bzl)-glu(ochex)-glu(ochex)-tyr(br-z)-cys(pmebzl)-oh
# onehot_targeting ligand_h2n-gly- l-phe-d-thr-gly-l-phe-l-leu-l-ser[o-b-d- glucose]-conh2; g7
# onehot_targeting ligand_her2 antibody
# onehot_targeting ligand_hiv-1 trans-activating protein (tat)
# onehot_targeting ligand_hiv-1 trans-activating protein (tat) and transferrin
# onehot_targeting ligand_i6p7
# onehot_targeting ligand_i6p7scr
# onehot_targeting ligand_igg2a-dspe-peg
# onehot_targeting ligand_igg4.1
# onehot_targeting ligand_il-13
# onehot_targeting ligand_il-13
# peptide
# onehot_targeting ligand_ingr(crngrgpdc)
# onehot_targeting ligand_insulin
# onehot_targeting ligand_integrin antagonist
# onehot_targeting ligand_internalizing tumor-penetrating peptide, irgd
# onehot_targeting ligand_irgd
# onehot_targeting ligand_irgd (ccrgdkgpdc)
# onehot_targeting ligand_irgd and tgn
# onehot_targeting ligand_isotye igg
# onehot_targeting ligand_item4 antibody
# onehot_targeting ligand_kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_l- disulfide system- glucose
# onehot_targeting ligand_l-ae
# onehot_targeting ligand_l-carnitine
# onehot_targeting ligand_lactoferrin
# onehot_targeting ligand_lactoferrin (lf)
# onehot_targeting ligand_lactofferin
# onehot_targeting ligand_langiopep
# onehot_targeting ligand_lc(lyp-1)(cgnkrtrgc)
# onehot_targeting ligand_lc(lyp-1)+d cdx
# onehot_targeting ligand_lcdx (fkeswreargtrierg)
# onehot_targeting ligand_lmwp
# onehot_targeting ligand_lvs (vswfsrhryspfavs)
# onehot_targeting ligand_maltobionic acid
# onehot_targeting ligand_mannose
# onehot_targeting ligand_mannose derivative
# onehot_targeting ligand_mastoparan
# onehot_targeting ligand_mmp-2-responsive peptides
# onehot_targeting ligand_monosialoganglioside
# onehot_targeting ligand_myristic acid (mc)
# onehot_targeting ligand_myristic acid-drdpdpdldwdtda, mc-da7r
# onehot_targeting ligand_n-acetyl pro-gly-pro
# onehot_targeting ligand_n-palmitoylglucosamine (npg)
# onehot_targeting ligand_nh2-gly-l-phe-d-thr-gly-l-phe-l-leu-l-ser(o-β-d-glucose)-cooh
# onehot_targeting ligand_nic-1
# onehot_targeting ligand_nic-2
# onehot_targeting ligand_none
# onehot_targeting ligand_octa-arginine (r8)
# onehot_targeting ligand_others
# onehot_targeting ligand_ox 26
# onehot_targeting ligand_ox26
# onehot_targeting ligand_ox26 and fab'
# onehot_targeting ligand_ox26-dspe-peg
# onehot_targeting ligand_p-amino-phenyl-a-d-mannopyranoside
# onehot_targeting ligand_p-aminophenyl-α-d-mannopyranoside
# onehot_targeting ligand_penetratin
# onehot_targeting ligand_penetrating peptide, rgd
# onehot_targeting ligand_pep-1 (cgemgwvrc) peptide
# onehot_targeting ligand_pep-1 peptide
# onehot_targeting ligand_pep-1 peptide；borneol(bor)
# onehot_targeting ligand_pep-1(cgemgwvrc)
# onehot_targeting ligand_pep-22
# onehot_targeting ligand_peptide-22 (nh2-c6-[cmprlrgc]c-nh2)
# onehot_targeting ligand_phenylalanine
# onehot_targeting ligand_phosphatidic acid (pa)
# onehot_targeting ligand_phosphatidylserine (ps)
# onehot_targeting ligand_pla
# onehot_targeting ligand_qlpvm
# onehot_targeting ligand_r6dgr
# onehot_targeting ligand_r8-rgd
# onehot_targeting ligand_r9f2
# onehot_targeting ligand_rabies virus glycoprotein-derived peptide
# onehot_targeting ligand_rgd
# onehot_targeting ligand_rgd-k
# onehot_targeting ligand_rgdk
# onehot_targeting ligand_rgdyk
# onehot_targeting ligand_rge(rgerppr)
# onehot_targeting ligand_rgek
# onehot_targeting ligand_ri-ae
# onehot_targeting ligand_ri7217.1.4
# onehot_targeting ligand_rmp-7
# onehot_targeting ligand_rqikiwfqnrrmkwkk
# onehot_targeting ligand_rvg
# onehot_targeting ligand_rvg29
# onehot_targeting ligand_rvg29 (twmpenprpgtpcdiftnsrgkrasnggggggc)
# onehot_targeting ligand_rvg29-biotin peptide (sequence: n term-ytiwmpenprpgtpcdiftnsrgkrasng-
# c2-biotin)
# onehot_targeting ligand_rvg29-cyspeptide
# onehot_targeting ligand_scrambled peptide (hwpyahpthpsw)
# onehot_targeting ligand_serine–arginine–leucine
# onehot_targeting ligand_solanum
# tuberosum lectin
# onehot_targeting ligand_specific peptide against tf receptor
# onehot_targeting ligand_srgd
# onehot_targeting ligand_stapled rgd
# onehot_targeting ligand_stearyl cyclic sls derivative (sls-str peptide)
# onehot_targeting ligand_sulfatide
# onehot_targeting ligand_t12
# (thrppmwspvwp) and mannose
# onehot_targeting ligand_t7 (haiyprh) peptide
# onehot_targeting ligand_t7 (haiyprh) peptide, tat (aygrkkrrqrrr) peptide
# onehot_targeting ligand_t7 序列： chaiyprh
# onehot_targeting ligand_tandem peptide of rgd and octarginine
# onehot_targeting ligand_tat
# onehot_targeting ligand_tat (aygrkkrrqrrr) peptide
# onehot_targeting ligand_tat-biotin peptide (sequence: biotin-ygrkkrrqrrr)
# onehot_targeting ligand_tat-peptide :tyr-gly-arg- (lys)2-(arg)2-gln-(arg)3
# onehot_targeting ligand_tgnykalhphngc
# onehot_targeting ligand_tgnykalhphngc, qshyrhispaqvc
# onehot_targeting ligand_thrppmwspvwp
# onehot_targeting ligand_tlyp-1
# onehot_targeting ligand_tlyp-1 and fhk
# onehot_targeting ligand_transferrin
# onehot_targeting ligand_transferrin (169 peptides)
# onehot_targeting ligand_transferrin (230 peptides)
# onehot_targeting ligand_transferrin (tf)
# onehot_targeting ligand_transferrin and penetratin
# onehot_targeting ligand_transferrin receptor (tfr) aptamer
# onehot_targeting ligand_transferrin+folic acid
# onehot_targeting ligand_transferrin-stearylamine
# onehot_targeting ligand_tumor-homing peptide creka
# onehot_targeting ligand_wga
# onehot_targeting ligand_wheat germ agglutinin
# onehot_targeting ligand_{succinyl[methoxy(polyethylene glycol)2000]} (peg2000-cer16) (cer-peg)
# onehot_targeting ligand_ glucose-peg1000-ch
# onehot_targeting ligand_ glucose-peg200-ch
# onehot_targeting ligand_ glucose-peg2000-ch
# onehot_targeting ligand_ glucose-peg400-ch
# onehot_targeting ligand_β-hydroxybutyric acid
# onehot_targeting ligand_细胞穿透肽tat (aygrkkrrqrrr)
# onehot_targeting ligand_细胞穿透肽tat (aygrkkrrqrrr)-peg-ch
# onehot_targeting ligand_血小板-内皮细胞黏附分子抗体
# onehot_animal model_alzheimer's disease
# onehot_animal model_brain tumor
# onehot_animal model_encephalomyelitis
# onehot_animal model_ischemic stroke
# onehot_animal model_normal
# onehot_animal model_others
# onehot_animal model_parkinson's disease
# onehot_animal model_stroke(ischemic stroke, hemorrhagic stroke)
# onehot_administration route_carotid artery injection
# onehot_administration route_convention-enhanced delivery (ced)
# onehot_administration route_i.n.
# onehot_administration route_i.p.
# onehot_administration route_i.t.
# onehot_administration route_i.v.
# onehot_administration route_none
# onehot_administration route_p.o.
# onehot_administration route_s.c.
# onehot_administration route_through carotid artery
# onehot_administration route_颈动脉注射
# onehot_type of the preparation_dendrimer
# onehot_type of the preparation_emulsion
# onehot_type of the preparation_extracellular vesicles
# onehot_type of the preparation_free drug
# onehot_type of the preparation_liposome
# onehot_type of the preparation_micelle
# onehot_type of the preparation_nanoparticles
# onehot_type of the preparation_none
# onehot_type of the preparation_others
# onehot_core composition of the preparation_plga
# onehot_core composition of the preparation_cholesterol
# onehot_core composition of the preparation_spc
# onehot_core composition of the preparation_au
# onehot_core composition of the preparation_pc
# onehot_core composition of the preparation_peg-pla
# onehot_core composition of the preparation_chitosan
# onehot_core composition of the preparation_dotap
# onehot_core composition of the preparation_dspe-peg
# onehot_core composition of the preparation_dope
# onehot_core composition of the preparation_epc
# onehot_core composition of the preparation_bovine serum albumin
# onehot_core composition of the preparation_spion
# onehot_core composition of the preparation_hspc
# onehot_core composition of the preparation_peg2000-dspe
# onehot_core composition of the preparation_dspe-peg2000
# onehot_core composition of the preparation_stearic acid
# onehot_core composition of the preparation_peg
# onehot_core composition of the preparation_pei
# onehot_core composition of the preparation_peg-plga
# onehot_core composition of the preparation_dspc
# onehot_core composition of the preparation_dppc
# onehot_core composition of the preparation_mpeg-pla
# onehot_core composition of the preparation_mpeg-pcl
# onehot_core composition of the preparation_dopc
# onehot_core composition of the preparation_glyceryl monostearate
# onehot_core composition of the preparation_mpeg2000-dspe
# onehot_core composition of the preparation_pamam
# onehot_core composition of the preparation_mpeg-pla2000
# onehot_core composition of the preparation_pva
# onehot_core composition of the preparation_peg-pcl
# onehot_core composition of the preparation_dspe
# onehot_core composition of the preparation_haucl4
# onehot_core composition of the preparation_cucl2
# onehot_core composition of the preparation_sio2
# onehot_core composition of the preparation_catechin hydrate
# onehot_core composition of the preparation_ps
# onehot_core composition of the preparation_dmpc
# onehot_core composition of the preparation_cetyl palmitate
# onehot_core composition of the preparation_nicotinamide
# onehot_core composition of the preparation_phospholpon 90g
# onehot_core composition of the preparation_male-peg-pla
# onehot_core composition of the preparation_peg-pamam
# onehot_core composition of the preparation_labrasol
# onehot_core composition of the preparation_cholestrol
# onehot_core composition of the preparation_tristearin
# onehot_core composition of the preparation_pla
# onehot_core composition of the preparation_n-butyl-cyanoacrylate
# onehot_core composition of the preparation_mal-peg-pla
# onehot_core composition of the preparation_lecithin
# onehot_core composition of the preparation_ir-775chloride(ir)
# onehot_core composition of the preparation_nppe
# onehot_core composition of the preparation_mc-peg3400-dspe
# onehot_core composition of the preparation_lipoid s75
# onehot_core composition of the preparation_fluorescent carboxylated-polystyrene
# onehot_core composition of the preparation_glycerol
# onehot_core composition of the preparation_plga-peg
# onehot_core composition of the preparation_glycerol monostearate
# onehot_core composition of the preparation_sodium stearate
# onehot_core composition of the preparation_pva9000
# onehot_core composition of the preparation_none
# onehot_core composition of the preparation_others
# onehot_type of targeting ligand_antibody
# onehot_type of targeting ligand_aptamer
# onehot_type of targeting ligand_cell-penetrating peptide
# onehot_type of targeting ligand_cell-penetrating peptide+transferrin
# onehot_type of targeting ligand_folic acid
# onehot_type of targeting ligand_glycosol
# onehot_type of targeting ligand_non-antibody protein
# onehot_type of targeting ligand_none
# onehot_type of targeting ligand_others
# onehot_type of targeting ligand_peptide
# onehot_type of targeting ligand_peptide and others
# onehot_targeting ligand_ lactoferrin
# onehot_targeting ligand_ n-acetyl pro–gly–pro (pgp)
# onehot_targeting ligand_ pep-1 (cgemgwvrc)
# onehot_targeting ligand_ r9f2
# onehot_targeting ligand_ r9f2+transferrin
# onehot_targeting ligand_ rabies virus glycoprotein (rvg) derivative
# onehot_targeting ligand_ tgn peptide (tgnykalhphng)
# onehot_targeting ligand_(tat)glyarglyslysargargglnargarg- argcysgly
# onehot_targeting ligand_15-amino acid peptide gyrpvhnirghwapg (gyr peptide)
# onehot_targeting ligand_8d3
# onehot_targeting ligand_a dual receptor recognizing cell penetrating peptiderrrrrrrrdgr (r8dgr, lower case letter representsd-amino acid residue)
# onehot_targeting ligand_acetylcholine,choline
# onehot_targeting ligand_acid-cleavable folic and kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_adenosine-based agonists
# onehot_targeting ligand_adipose-derived stem cells
# onehot_targeting ligand_amyloid beta
# onehot_targeting ligand_amyloid precursor protein
# onehot_targeting ligand_angiopep-2
# onehot_targeting ligand_angiopep-2
#
# onehot_targeting ligand_angiopep-2 (ang, tffyggsrgkrnnfkteey
# onehot_targeting ligand_angiopep-2 (tffyggsrgkrnnfkteeyc)
# onehot_targeting ligand_angiopep-2(tffyggsrgkrnnfkteeyc)
# onehot_targeting ligand_anti-nestin antibody
# onehot_targeting ligand_anti-nestin antibody，transferrin antibody
# onehot_targeting ligand_anti-pdgfrβ aptamer
# onehot_targeting ligand_anti-pirb antibody
# onehot_targeting ligand_anti-tfra
# onehot_targeting ligand_anti-tfra/bace1
# onehot_targeting ligand_anti-tfrd
# onehot_targeting ligand_anti-transferrin receptor antibody (8d3)-pegdspe
# onehot_targeting ligand_anti-vcam-1 antibody
# onehot_targeting ligand_ap1
# onehot_targeting ligand_apoe mimetic peptide
# onehot_targeting ligand_apolipopretoein e
# onehot_targeting ligand_aprotinin
# onehot_targeting ligand_arg-ala-asp (rad)
# onehot_targeting ligand_arg-gly-asp (rgd)
# onehot_targeting ligand_arg-gly-asp (rgd)+il-13
# onehot_targeting ligand_arginine–glycine–aspartic acid (rgd)
# onehot_targeting ligand_ascorbic acid
# onehot_targeting ligand_asn-gly-arg (ngr)
# onehot_targeting ligand_atwlppr
# onehot_targeting ligand_b6
# onehot_targeting ligand_b6+mazindol
# onehot_targeting ligand_bevacizumab
# onehot_targeting ligand_biotin
# onehot_targeting ligand_bombesin peptide (gqwavghlm)
# onehot_targeting ligand_borneol
# onehot_targeting ligand_bovine lf
# onehot_targeting ligand_c*nnskshtc*
# onehot_targeting ligand_cd 47
# onehot_targeting ligand_cdx peptide
# onehot_targeting ligand_cell-penetrating peptide tat
# onehot_targeting ligand_cereport (rmp-7)-pegdspe
# onehot_targeting ligand_cgcrk
# onehot_targeting ligand_cgkrk
# onehot_targeting ligand_cgkrk &  pep-1 (cgemgwvrc)
# onehot_targeting ligand_cgkrkgygatwllppr
# onehot_targeting ligand_chlorotoxin
# onehot_targeting ligand_cholera toxin b subunit
# onehot_targeting ligand_chondroitin sulfate
# onehot_targeting ligand_clpffd
# onehot_targeting ligand_cngr(cngrcg)
# onehot_targeting ligand_cpps-tat
# onehot_targeting ligand_creka
# onehot_targeting ligand_crgd
# onehot_targeting ligand_crgd(arg-gly-asp)
# onehot_targeting ligand_csspiqgswtwengk(c)wtwgiirleq
# onehot_targeting ligand_cvsrrrrrrggrrrr
# onehot_targeting ligand_cylic rgd
# onehot_targeting ligand_d cdx(greirtgraerwsekf)
# onehot_targeting ligand_d-ae
# onehot_targeting ligand_da7r (drdpdpdldwdtda)
# onehot_targeting ligand_dangiopep
# onehot_targeting ligand_dc(lyp-1)(cgnkrtrgc)
# onehot_targeting ligand_dc(lyp-1)+d cdx
# onehot_targeting ligand_dcdx, the retro–inverso isomer oflcdx,
# onehot_targeting ligand_dehydroascorbic acid
# onehot_targeting ligand_dspe-peg-rvg29 peptide
# onehot_targeting ligand_dspe-peg-triphenylphosphine (tpp)
# onehot_targeting ligand_dspe-peg-triphenylphosphine (tpp)+dspe-peg-rvg29 peptide
# onehot_targeting ligand_dspepeg-mannose
# onehot_targeting ligand_dspepeg-mannose/dspepeg-transferrin
# onehot_targeting ligand_dspepeg-transferrin
# onehot_targeting ligand_dvs (vswfsrhryspfavs)
# onehot_targeting ligand_edb-targeted peptide apt
# onehot_targeting ligand_egfp-egf1 (a protein derived from factor vii )
# onehot_targeting ligand_egfr-targeting peptide (yhwygytpqnvi)
# onehot_targeting ligand_fhk(fhkhkspalspv)
# onehot_targeting ligand_fibrin-binding peptide (creka)
# onehot_targeting ligand_folic
# onehot_targeting ligand_folic acid
# onehot_targeting ligand_folic acid (fa)
# onehot_targeting ligand_folic and kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_fucose
# derivative (l-type)
# onehot_targeting ligand_fucose
# derivative (r-type)
# onehot_targeting ligand_galactose derivative
# onehot_targeting ligand_glucose
# onehot_targeting ligand_glutathione
# onehot_targeting ligand_glutathione
# onehot_targeting ligand_gly-arg-lys-lys-arg-arg-gln-arg-arg-arg- gly (tat)
# onehot_targeting ligand_gly-l- phe-d-thr-gly-l-phe-l-leu-l-ser(o-β-d-glucose)- conh2.
# onehot_targeting ligand_h-thr(bzl)-phe-phe-tyr(br-z)-gly-gly-ser(bzl)-arg(tos)-gly-lys(cl-z)-arg(tos)-asn(xan)-asn(xan)-phe-lys(cl-z)-thr(bzl)-glu(ochex)-glu(ochex)-tyr(br-z)-cys(pmebzl)-oh
# onehot_targeting ligand_h2n-gly- l-phe-d-thr-gly-l-phe-l-leu-l-ser[o-b-d- glucose]-conh2; g7
# onehot_targeting ligand_her2 antibody
# onehot_targeting ligand_hiv-1 trans-activating protein (tat)
# onehot_targeting ligand_hiv-1 trans-activating protein (tat) and transferrin
# onehot_targeting ligand_i6p7
# onehot_targeting ligand_i6p7scr
# onehot_targeting ligand_igg2a-dspe-peg
# onehot_targeting ligand_igg4.1
# onehot_targeting ligand_il-13
# onehot_targeting ligand_il-13
# peptide
# onehot_targeting ligand_ingr(crngrgpdc)
# onehot_targeting ligand_insulin
# onehot_targeting ligand_integrin antagonist
# onehot_targeting ligand_internalizing tumor-penetrating peptide, irgd
# onehot_targeting ligand_irgd
# onehot_targeting ligand_irgd (ccrgdkgpdc)
# onehot_targeting ligand_irgd and tgn
# onehot_targeting ligand_isotye igg
# onehot_targeting ligand_item4 antibody
# onehot_targeting ligand_kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_l- disulfide system- glucose
# onehot_targeting ligand_l-ae
# onehot_targeting ligand_l-carnitine
# onehot_targeting ligand_lactoferrin
# onehot_targeting ligand_lactoferrin (lf)
# onehot_targeting ligand_lactofferin
# onehot_targeting ligand_langiopep
# onehot_targeting ligand_lc(lyp-1)(cgnkrtrgc)
# onehot_targeting ligand_lc(lyp-1)+d cdx
# onehot_targeting ligand_lcdx (fkeswreargtrierg)
# onehot_targeting ligand_lmwp
# onehot_targeting ligand_lvs (vswfsrhryspfavs)
# onehot_targeting ligand_maltobionic acid
# onehot_targeting ligand_mannose
# onehot_targeting ligand_mannose derivative
# onehot_targeting ligand_mastoparan
# onehot_targeting ligand_mmp-2-responsive peptides
# onehot_targeting ligand_monosialoganglioside
# onehot_targeting ligand_myristic acid (mc)
# onehot_targeting ligand_myristic acid-drdpdpdldwdtda, mc-da7r
# onehot_targeting ligand_n-acetyl pro-gly-pro
# onehot_targeting ligand_n-palmitoylglucosamine (npg)
# onehot_targeting ligand_nh2-gly-l-phe-d-thr-gly-l-phe-l-leu-l-ser(o-β-d-glucose)-cooh
# onehot_targeting ligand_nic-1
# onehot_targeting ligand_nic-2
# onehot_targeting ligand_none
# onehot_targeting ligand_octa-arginine (r8)
# onehot_targeting ligand_others
# onehot_targeting ligand_ox 26
# onehot_targeting ligand_ox26
# onehot_targeting ligand_ox26 and fab'
# onehot_targeting ligand_ox26-dspe-peg
# onehot_targeting ligand_p-amino-phenyl-a-d-mannopyranoside
# onehot_targeting ligand_p-aminophenyl-α-d-mannopyranoside
# onehot_targeting ligand_penetratin
# onehot_targeting ligand_penetrating peptide, rgd
# onehot_targeting ligand_pep-1 (cgemgwvrc) peptide
# onehot_targeting ligand_pep-1 peptide
# onehot_targeting ligand_pep-1 peptide；borneol(bor)
# onehot_targeting ligand_pep-1(cgemgwvrc)
# onehot_targeting ligand_pep-22
# onehot_targeting ligand_peptide-22 (nh2-c6-[cmprlrgc]c-nh2)
# onehot_targeting ligand_phenylalanine
# onehot_targeting ligand_phosphatidic acid (pa)
# onehot_targeting ligand_phosphatidylserine (ps)
# onehot_targeting ligand_pla
# onehot_targeting ligand_qlpvm
# onehot_targeting ligand_r6dgr
# onehot_targeting ligand_r8-rgd
# onehot_targeting ligand_r9f2
# onehot_targeting ligand_rabies virus glycoprotein-derived peptide
# onehot_targeting ligand_rgd
# onehot_targeting ligand_rgd-k
# onehot_targeting ligand_rgdk
# onehot_targeting ligand_rgdyk
# onehot_targeting ligand_rge(rgerppr)
# onehot_targeting ligand_rgek
# onehot_targeting ligand_ri-ae
# onehot_targeting ligand_ri7217.1.4
# onehot_targeting ligand_rmp-7
# onehot_targeting ligand_rqikiwfqnrrmkwkk
# onehot_targeting ligand_rvg
# onehot_targeting ligand_rvg29
# onehot_targeting ligand_rvg29 (twmpenprpgtpcdiftnsrgkrasnggggggc)
# onehot_targeting ligand_rvg29-biotin peptide (sequence: n term-ytiwmpenprpgtpcdiftnsrgkrasng-
# c2-biotin)
# onehot_targeting ligand_rvg29-cyspeptide
# onehot_targeting ligand_scrambled peptide (hwpyahpthpsw)
# onehot_targeting ligand_serine–arginine–leucine
# onehot_targeting ligand_solanum
# tuberosum lectin
# onehot_targeting ligand_specific peptide against tf receptor
# onehot_targeting ligand_srgd
# onehot_targeting ligand_stapled rgd
# onehot_targeting ligand_stearyl cyclic sls derivative (sls-str peptide)
# onehot_targeting ligand_sulfatide
# onehot_targeting ligand_t12
# (thrppmwspvwp) and mannose
# onehot_targeting ligand_t7 (haiyprh) peptide
# onehot_targeting ligand_t7 (haiyprh) peptide, tat (aygrkkrrqrrr) peptide
# onehot_targeting ligand_t7 序列： chaiyprh
# onehot_targeting ligand_tandem peptide of rgd and octarginine
# onehot_targeting ligand_tat
# onehot_targeting ligand_tat (aygrkkrrqrrr) peptide
# onehot_targeting ligand_tat-biotin peptide (sequence: biotin-ygrkkrrqrrr)
# onehot_targeting ligand_tat-peptide :tyr-gly-arg- (lys)2-(arg)2-gln-(arg)3
# onehot_targeting ligand_tgnykalhphngc
# onehot_targeting ligand_tgnykalhphngc, qshyrhispaqvc
# onehot_targeting ligand_thrppmwspvwp
# onehot_targeting ligand_tlyp-1
# onehot_targeting ligand_tlyp-1 and fhk
# onehot_targeting ligand_transferrin
# onehot_targeting ligand_transferrin (169 peptides)
# onehot_targeting ligand_transferrin (230 peptides)
# onehot_targeting ligand_transferrin (tf)
# onehot_targeting ligand_transferrin and penetratin
# onehot_targeting ligand_transferrin receptor (tfr) aptamer
# onehot_targeting ligand_transferrin+folic acid
# onehot_targeting ligand_transferrin-stearylamine
# onehot_targeting ligand_tumor-homing peptide creka
# onehot_targeting ligand_wga
# onehot_targeting ligand_wheat germ agglutinin
# onehot_targeting ligand_{succinyl[methoxy(polyethylene glycol)2000]} (peg2000-cer16) (cer-peg)
# onehot_targeting ligand_ glucose-peg1000-ch
# onehot_targeting ligand_ glucose-peg200-ch
# onehot_targeting ligand_ glucose-peg2000-ch
# onehot_targeting ligand_ glucose-peg400-ch
# onehot_targeting ligand_β-hydroxybutyric acid
# onehot_targeting ligand_细胞穿透肽tat (aygrkkrrqrrr)
# onehot_targeting ligand_细胞穿透肽tat (aygrkkrrqrrr)-peg-ch
# onehot_targeting ligand_血小板-内皮细胞黏附分子抗体
# onehot_animal model_alzheimer's disease
# onehot_animal model_brain tumor
# onehot_animal model_encephalomyelitis
# onehot_animal model_ischemic stroke
# onehot_animal model_normal
# onehot_animal model_others
# onehot_animal model_parkinson's disease
# onehot_animal model_stroke(ischemic stroke, hemorrhagic stroke)
# onehot_administration route_carotid artery injection
# onehot_administration route_convention-enhanced delivery (ced)
# onehot_administration route_i.n.
# onehot_administration route_i.p.
# onehot_administration route_i.t.
# onehot_administration route_i.v.
# onehot_administration route_none
# onehot_administration route_p.o.
# onehot_administration route_s.c.
# onehot_administration route_through carotid artery
# onehot_administration route_颈动脉注射
# onehot_type of the preparation_dendrimer
# onehot_type of the preparation_emulsion
# onehot_type of the preparation_extracellular vesicles
# onehot_type of the preparation_free drug
# onehot_type of the preparation_liposome
# onehot_type of the preparation_micelle
# onehot_type of the preparation_nanoparticles
# onehot_type of the preparation_none
# onehot_type of the preparation_others
# onehot_core composition of the preparation_plga
# onehot_core composition of the preparation_cholesterol
# onehot_core composition of the preparation_spc
# onehot_core composition of the preparation_au
# onehot_core composition of the preparation_pc
# onehot_core composition of the preparation_peg-pla
# onehot_core composition of the preparation_chitosan
# onehot_core composition of the preparation_dotap
# onehot_core composition of the preparation_dspe-peg
# onehot_core composition of the preparation_dope
# onehot_core composition of the preparation_epc
# onehot_core composition of the preparation_bovine serum albumin
# onehot_core composition of the preparation_spion
# onehot_core composition of the preparation_hspc
# onehot_core composition of the preparation_peg2000-dspe
# onehot_core composition of the preparation_dspe-peg2000
# onehot_core composition of the preparation_stearic acid
# onehot_core composition of the preparation_peg
# onehot_core composition of the preparation_pei
# onehot_core composition of the preparation_peg-plga
# onehot_core composition of the preparation_dspc
# onehot_core composition of the preparation_dppc
# onehot_core composition of the preparation_mpeg-pla
# onehot_core composition of the preparation_mpeg-pcl
# onehot_core composition of the preparation_dopc
# onehot_core composition of the preparation_glyceryl monostearate
# onehot_core composition of the preparation_mpeg2000-dspe
# onehot_core composition of the preparation_pamam
# onehot_core composition of the preparation_mpeg-pla2000
# onehot_core composition of the preparation_pva
# onehot_core composition of the preparation_peg-pcl
# onehot_core composition of the preparation_dspe
# onehot_core composition of the preparation_haucl4
# onehot_core composition of the preparation_cucl2
# onehot_core composition of the preparation_sio2
# onehot_core composition of the preparation_catechin hydrate
# onehot_core composition of the preparation_ps
# onehot_core composition of the preparation_dmpc
# onehot_core composition of the preparation_cetyl palmitate
# onehot_core composition of the preparation_nicotinamide
# onehot_core composition of the preparation_phospholpon 90g
# onehot_core composition of the preparation_male-peg-pla
# onehot_core composition of the preparation_peg-pamam
# onehot_core composition of the preparation_labrasol
# onehot_core composition of the preparation_cholestrol
# onehot_core composition of the preparation_tristearin
# onehot_core composition of the preparation_pla
# onehot_core composition of the preparation_n-butyl-cyanoacrylate
# onehot_core composition of the preparation_mal-peg-pla
# onehot_core composition of the preparation_lecithin
# onehot_core composition of the preparation_ir-775chloride(ir)
# onehot_core composition of the preparation_nppe
# onehot_core composition of the preparation_mc-peg3400-dspe
# onehot_core composition of the preparation_lipoid s75
# onehot_core composition of the preparation_fluorescent carboxylated-polystyrene
# onehot_core composition of the preparation_glycerol
# onehot_core composition of the preparation_plga-peg
# onehot_core composition of the preparation_glycerol monostearate
# onehot_core composition of the preparation_sodium stearate
# onehot_core composition of the preparation_pva9000
# onehot_core composition of the preparation_none
# onehot_core composition of the preparation_others
# onehot_type of targeting ligand_antibody
# onehot_type of targeting ligand_aptamer
# onehot_type of targeting ligand_cell-penetrating peptide
# onehot_type of targeting ligand_cell-penetrating peptide+transferrin
# onehot_type of targeting ligand_folic acid
# onehot_type of targeting ligand_glycosol
# onehot_type of targeting ligand_non-antibody protein
# onehot_type of targeting ligand_none
# onehot_type of targeting ligand_others
# onehot_type of targeting ligand_peptide
# onehot_type of targeting ligand_peptide and others
# onehot_targeting ligand_ lactoferrin
# onehot_targeting ligand_ n-acetyl pro–gly–pro (pgp)
# onehot_targeting ligand_ pep-1 (cgemgwvrc)
# onehot_targeting ligand_ r9f2
# onehot_targeting ligand_ r9f2+transferrin
# onehot_targeting ligand_ rabies virus glycoprotein (rvg) derivative
# onehot_targeting ligand_ tgn peptide (tgnykalhphng)
# onehot_targeting ligand_(tat)glyarglyslysargargglnargarg- argcysgly
# onehot_targeting ligand_15-amino acid peptide gyrpvhnirghwapg (gyr peptide)
# onehot_targeting ligand_8d3
# onehot_targeting ligand_a dual receptor recognizing cell penetrating peptiderrrrrrrrdgr (r8dgr, lower case letter representsd-amino acid residue)
# onehot_targeting ligand_acetylcholine,choline
# onehot_targeting ligand_acid-cleavable folic and kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_adenosine-based agonists
# onehot_targeting ligand_adipose-derived stem cells
# onehot_targeting ligand_amyloid beta
# onehot_targeting ligand_amyloid precursor protein
# onehot_targeting ligand_angiopep-2
# onehot_targeting ligand_angiopep-2
#
# onehot_targeting ligand_angiopep-2 (ang, tffyggsrgkrnnfkteey
# onehot_targeting ligand_angiopep-2 (tffyggsrgkrnnfkteeyc)
# onehot_targeting ligand_angiopep-2(tffyggsrgkrnnfkteeyc)
# onehot_targeting ligand_anti-nestin antibody
# onehot_targeting ligand_anti-nestin antibody，transferrin antibody
# onehot_targeting ligand_anti-pdgfrβ aptamer
# onehot_targeting ligand_anti-pirb antibody
# onehot_targeting ligand_anti-tfra
# onehot_targeting ligand_anti-tfra/bace1
# onehot_targeting ligand_anti-tfrd
# onehot_targeting ligand_anti-transferrin receptor antibody (8d3)-pegdspe
# onehot_targeting ligand_anti-vcam-1 antibody
# onehot_targeting ligand_ap1
# onehot_targeting ligand_apoe mimetic peptide
# onehot_targeting ligand_apolipopretoein e
# onehot_targeting ligand_aprotinin
# onehot_targeting ligand_arg-ala-asp (rad)
# onehot_targeting ligand_arg-gly-asp (rgd)
# onehot_targeting ligand_arg-gly-asp (rgd)+il-13
# onehot_targeting ligand_arginine–glycine–aspartic acid (rgd)
# onehot_targeting ligand_ascorbic acid
# onehot_targeting ligand_asn-gly-arg (ngr)
# onehot_targeting ligand_atwlppr
# onehot_targeting ligand_b6
# onehot_targeting ligand_b6+mazindol
# onehot_targeting ligand_bevacizumab
# onehot_targeting ligand_biotin
# onehot_targeting ligand_bombesin peptide (gqwavghlm)
# onehot_targeting ligand_borneol
# onehot_targeting ligand_bovine lf
# onehot_targeting ligand_c*nnskshtc*
# onehot_targeting ligand_cd 47
# onehot_targeting ligand_cdx peptide
# onehot_targeting ligand_cell-penetrating peptide tat
# onehot_targeting ligand_cereport (rmp-7)-pegdspe
# onehot_targeting ligand_cgcrk
# onehot_targeting ligand_cgkrk
# onehot_targeting ligand_cgkrk &  pep-1 (cgemgwvrc)
# onehot_targeting ligand_cgkrkgygatwllppr
# onehot_targeting ligand_chlorotoxin
# onehot_targeting ligand_cholera toxin b subunit
# onehot_targeting ligand_chondroitin sulfate
# onehot_targeting ligand_clpffd
# onehot_targeting ligand_cngr(cngrcg)
# onehot_targeting ligand_cpps-tat
# onehot_targeting ligand_creka
# onehot_targeting ligand_crgd
# onehot_targeting ligand_crgd(arg-gly-asp)
# onehot_targeting ligand_csspiqgswtwengk(c)wtwgiirleq
# onehot_targeting ligand_cvsrrrrrrggrrrr
# onehot_targeting ligand_cylic rgd
# onehot_targeting ligand_d cdx(greirtgraerwsekf)
# onehot_targeting ligand_d-ae
# onehot_targeting ligand_da7r (drdpdpdldwdtda)
# onehot_targeting ligand_dangiopep
# onehot_targeting ligand_dc(lyp-1)(cgnkrtrgc)
# onehot_targeting ligand_dc(lyp-1)+d cdx
# onehot_targeting ligand_dcdx, the retro–inverso isomer oflcdx,
# onehot_targeting ligand_dehydroascorbic acid
# onehot_targeting ligand_dspe-peg-rvg29 peptide
# onehot_targeting ligand_dspe-peg-triphenylphosphine (tpp)
# onehot_targeting ligand_dspe-peg-triphenylphosphine (tpp)+dspe-peg-rvg29 peptide
# onehot_targeting ligand_dspepeg-mannose
# onehot_targeting ligand_dspepeg-mannose/dspepeg-transferrin
# onehot_targeting ligand_dspepeg-transferrin
# onehot_targeting ligand_dvs (vswfsrhryspfavs)
# onehot_targeting ligand_edb-targeted peptide apt
# onehot_targeting ligand_egfp-egf1 (a protein derived from factor vii )
# onehot_targeting ligand_egfr-targeting peptide (yhwygytpqnvi)
# onehot_targeting ligand_fhk(fhkhkspalspv)
# onehot_targeting ligand_fibrin-binding peptide (creka)
# onehot_targeting ligand_folic
# onehot_targeting ligand_folic acid
# onehot_targeting ligand_folic acid (fa)
# onehot_targeting ligand_folic and kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_fucose
# derivative (l-type)
# onehot_targeting ligand_fucose
# derivative (r-type)
# onehot_targeting ligand_galactose derivative
# onehot_targeting ligand_glucose
# onehot_targeting ligand_glutathione
# onehot_targeting ligand_glutathione
# onehot_targeting ligand_gly-arg-lys-lys-arg-arg-gln-arg-arg-arg- gly (tat)
# onehot_targeting ligand_gly-l- phe-d-thr-gly-l-phe-l-leu-l-ser(o-β-d-glucose)- conh2.
# onehot_targeting ligand_h-thr(bzl)-phe-phe-tyr(br-z)-gly-gly-ser(bzl)-arg(tos)-gly-lys(cl-z)-arg(tos)-asn(xan)-asn(xan)-phe-lys(cl-z)-thr(bzl)-glu(ochex)-glu(ochex)-tyr(br-z)-cys(pmebzl)-oh
# onehot_targeting ligand_h2n-gly- l-phe-d-thr-gly-l-phe-l-leu-l-ser[o-b-d- glucose]-conh2; g7
# onehot_targeting ligand_her2 antibody
# onehot_targeting ligand_hiv-1 trans-activating protein (tat)
# onehot_targeting ligand_hiv-1 trans-activating protein (tat) and transferrin
# onehot_targeting ligand_i6p7
# onehot_targeting ligand_i6p7scr
# onehot_targeting ligand_igg2a-dspe-peg
# onehot_targeting ligand_igg4.1
# onehot_targeting ligand_il-13
# onehot_targeting ligand_il-13
# peptide
# onehot_targeting ligand_ingr(crngrgpdc)
# onehot_targeting ligand_insulin
# onehot_targeting ligand_integrin antagonist
# onehot_targeting ligand_internalizing tumor-penetrating peptide, irgd
# onehot_targeting ligand_irgd
# onehot_targeting ligand_irgd (ccrgdkgpdc)
# onehot_targeting ligand_irgd and tgn
# onehot_targeting ligand_isotye igg
# onehot_targeting ligand_item4 antibody
# onehot_targeting ligand_kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_l- disulfide system- glucose
# onehot_targeting ligand_l-ae
# onehot_targeting ligand_l-carnitine
# onehot_targeting ligand_lactoferrin
# onehot_targeting ligand_lactoferrin (lf)
# onehot_targeting ligand_lactofferin
# onehot_targeting ligand_langiopep
# onehot_targeting ligand_lc(lyp-1)(cgnkrtrgc)
# onehot_targeting ligand_lc(lyp-1)+d cdx
# onehot_targeting ligand_lcdx (fkeswreargtrierg)
# onehot_targeting ligand_lmwp
# onehot_targeting ligand_lvs (vswfsrhryspfavs)
# onehot_targeting ligand_maltobionic acid
# onehot_targeting ligand_mannose
# onehot_targeting ligand_mannose derivative
# onehot_targeting ligand_mastoparan
# onehot_targeting ligand_mmp-2-responsive peptides
# onehot_targeting ligand_monosialoganglioside
# onehot_targeting ligand_myristic acid (mc)
# onehot_targeting ligand_myristic acid-drdpdpdldwdtda, mc-da7r
# onehot_targeting ligand_n-acetyl pro-gly-pro
# onehot_targeting ligand_n-palmitoylglucosamine (npg)
# onehot_targeting ligand_nh2-gly-l-phe-d-thr-gly-l-phe-l-leu-l-ser(o-β-d-glucose)-cooh
# onehot_targeting ligand_nic-1
# onehot_targeting ligand_nic-2
# onehot_targeting ligand_none
# onehot_targeting ligand_octa-arginine (r8)
# onehot_targeting ligand_others
# onehot_targeting ligand_ox 26
# onehot_targeting ligand_ox26
# onehot_targeting ligand_ox26 and fab'
# onehot_targeting ligand_ox26-dspe-peg
# onehot_targeting ligand_p-amino-phenyl-a-d-mannopyranoside
# onehot_targeting ligand_p-aminophenyl-α-d-mannopyranoside
# onehot_targeting ligand_penetratin
# onehot_targeting ligand_penetrating peptide, rgd
# onehot_targeting ligand_pep-1 (cgemgwvrc) peptide
# onehot_targeting ligand_pep-1 peptide
# onehot_targeting ligand_pep-1 peptide；borneol(bor)
# onehot_targeting ligand_pep-1(cgemgwvrc)
# onehot_targeting ligand_pep-22
# onehot_targeting ligand_peptide-22 (nh2-c6-[cmprlrgc]c-nh2)
# onehot_targeting ligand_phenylalanine
# onehot_targeting ligand_phosphatidic acid (pa)
# onehot_targeting ligand_phosphatidylserine (ps)
# onehot_targeting ligand_pla
# onehot_targeting ligand_qlpvm
# onehot_targeting ligand_r6dgr
# onehot_targeting ligand_r8-rgd
# onehot_targeting ligand_r9f2
# onehot_targeting ligand_rabies virus glycoprotein-derived peptide
# onehot_targeting ligand_rgd
# onehot_targeting ligand_rgd-k
# onehot_targeting ligand_rgdk
# onehot_targeting ligand_rgdyk
# onehot_targeting ligand_rge(rgerppr)
# onehot_targeting ligand_rgek
# onehot_targeting ligand_ri-ae
# onehot_targeting ligand_ri7217.1.4
# onehot_targeting ligand_rmp-7
# onehot_targeting ligand_rqikiwfqnrrmkwkk
# onehot_targeting ligand_rvg
# onehot_targeting ligand_rvg29
# onehot_targeting ligand_rvg29 (twmpenprpgtpcdiftnsrgkrasnggggggc)
# onehot_targeting ligand_rvg29-biotin peptide (sequence: n term-ytiwmpenprpgtpcdiftnsrgkrasng-
# c2-biotin)
# onehot_targeting ligand_rvg29-cyspeptide
# onehot_targeting ligand_scrambled peptide (hwpyahpthpsw)
# onehot_targeting ligand_serine–arginine–leucine
# onehot_targeting ligand_solanum
# tuberosum lectin
# onehot_targeting ligand_specific peptide against tf receptor
# onehot_targeting ligand_srgd
# onehot_targeting ligand_stapled rgd
# onehot_targeting ligand_stearyl cyclic sls derivative (sls-str peptide)
# onehot_targeting ligand_sulfatide
# onehot_targeting ligand_t12
# (thrppmwspvwp) and mannose
# onehot_targeting ligand_t7 (haiyprh) peptide
# onehot_targeting ligand_t7 (haiyprh) peptide, tat (aygrkkrrqrrr) peptide
# onehot_targeting ligand_t7 序列： chaiyprh
# onehot_targeting ligand_tandem peptide of rgd and octarginine
# onehot_targeting ligand_tat
# onehot_targeting ligand_tat (aygrkkrrqrrr) peptide
# onehot_targeting ligand_tat-biotin peptide (sequence: biotin-ygrkkrrqrrr)
# onehot_targeting ligand_tat-peptide :tyr-gly-arg- (lys)2-(arg)2-gln-(arg)3
# onehot_targeting ligand_tgnykalhphngc
# onehot_targeting ligand_tgnykalhphngc, qshyrhispaqvc
# onehot_targeting ligand_thrppmwspvwp
# onehot_targeting ligand_tlyp-1
# onehot_targeting ligand_tlyp-1 and fhk
# onehot_targeting ligand_transferrin
# onehot_targeting ligand_transferrin (169 peptides)
# onehot_targeting ligand_transferrin (230 peptides)
# onehot_targeting ligand_transferrin (tf)
# onehot_targeting ligand_transferrin and penetratin
# onehot_targeting ligand_transferrin receptor (tfr) aptamer
# onehot_targeting ligand_transferrin+folic acid
# onehot_targeting ligand_transferrin-stearylamine
# onehot_targeting ligand_tumor-homing peptide creka
# onehot_targeting ligand_wga
# onehot_targeting ligand_wheat germ agglutinin
# onehot_targeting ligand_{succinyl[methoxy(polyethylene glycol)2000]} (peg2000-cer16) (cer-peg)
# onehot_targeting ligand_ glucose-peg1000-ch
# onehot_targeting ligand_ glucose-peg200-ch
# onehot_targeting ligand_ glucose-peg2000-ch
# onehot_targeting ligand_ glucose-peg400-ch
# onehot_targeting ligand_β-hydroxybutyric acid
# onehot_targeting ligand_细胞穿透肽tat (aygrkkrrqrrr)
# onehot_targeting ligand_细胞穿透肽tat (aygrkkrrqrrr)-peg-ch
# onehot_targeting ligand_血小板-内皮细胞黏附分子抗体
# onehot_animal model_alzheimer's disease
# onehot_animal model_brain tumor
# onehot_animal model_encephalomyelitis
# onehot_animal model_ischemic stroke
# onehot_animal model_normal
# onehot_animal model_others
# onehot_animal model_parkinson's disease
# onehot_animal model_stroke(ischemic stroke, hemorrhagic stroke)
# onehot_administration route_carotid artery injection
# onehot_administration route_convention-enhanced delivery (ced)
# onehot_administration route_i.n.
# onehot_administration route_i.p.
# onehot_administration route_i.t.
# onehot_administration route_i.v.
# onehot_administration route_none
# onehot_administration route_p.o.
# onehot_administration route_s.c.
# onehot_administration route_through carotid artery
# onehot_administration route_颈动脉注射
# onehot_type of the preparation_dendrimer
# onehot_type of the preparation_emulsion
# onehot_type of the preparation_extracellular vesicles
# onehot_type of the preparation_free drug
# onehot_type of the preparation_liposome
# onehot_type of the preparation_micelle
# onehot_type of the preparation_nanoparticles
# onehot_type of the preparation_none
# onehot_type of the preparation_others
# onehot_core composition of the preparation_plga
# onehot_core composition of the preparation_cholesterol
# onehot_core composition of the preparation_spc
# onehot_core composition of the preparation_au
# onehot_core composition of the preparation_pc
# onehot_core composition of the preparation_peg-pla
# onehot_core composition of the preparation_chitosan
# onehot_core composition of the preparation_dotap
# onehot_core composition of the preparation_dspe-peg
# onehot_core composition of the preparation_dope
# onehot_core composition of the preparation_epc
# onehot_core composition of the preparation_bovine serum albumin
# onehot_core composition of the preparation_spion
# onehot_core composition of the preparation_hspc
# onehot_core composition of the preparation_peg2000-dspe
# onehot_core composition of the preparation_dspe-peg2000
# onehot_core composition of the preparation_stearic acid
# onehot_core composition of the preparation_peg
# onehot_core composition of the preparation_pei
# onehot_core composition of the preparation_peg-plga
# onehot_core composition of the preparation_dspc
# ...
# onehot_administration route_carotid artery injection
# onehot_administration route_convention-enhanced delivery (ced)
# onehot_administration route_i.n.
# onehot_administration route_i.p.
# onehot_administration route_i.t.
# onehot_administration route_i.v.
# onehot_administration route_none
# onehot_administration route_p.o.
# onehot_administration route_s.c.
# onehot_administration route_through carotid artery
# onehot_administration route_颈动脉注射
# onehot_type of the preparation_dendrimer
# onehot_type of the preparation_emulsion
# onehot_type of the preparation_extracellular vesicles
# onehot_type of the preparation_free drug
# onehot_type of the preparation_liposome
# onehot_type of the preparation_micelle
# onehot_type of the preparation_nanoparticles
# onehot_type of the preparation_none
# onehot_type of the preparation_others
# onehot_core composition of the preparation_plga
# onehot_core composition of the preparation_cholesterol
# onehot_core composition of the preparation_spc
# onehot_core composition of the preparation_au
# onehot_core composition of the preparation_pc
# onehot_core composition of the preparation_peg-pla
# onehot_core composition of the preparation_chitosan
# onehot_core composition of the preparation_dotap
# onehot_core composition of the preparation_dspe-peg
# onehot_core composition of the preparation_dope
# onehot_core composition of the preparation_epc
# onehot_core composition of the preparation_bovine serum albumin
# onehot_core composition of the preparation_spion
# onehot_core composition of the preparation_hspc
# onehot_core composition of the preparation_peg2000-dspe
# onehot_core composition of the preparation_dspe-peg2000
# onehot_core composition of the preparation_stearic acid
# onehot_core composition of the preparation_peg
# onehot_core composition of the preparation_pei
# onehot_core composition of the preparation_peg-plga
# onehot_core composition of the preparation_dspc
# onehot_core composition of the preparation_dppc
# onehot_core composition of the preparation_mpeg-pla
# onehot_core composition of the preparation_mpeg-pcl
# onehot_core composition of the preparation_dopc
# onehot_core composition of the preparation_glyceryl monostearate
# onehot_core composition of the preparation_mpeg2000-dspe
# onehot_core composition of the preparation_pamam
# onehot_core composition of the preparation_mpeg-pla2000
# onehot_core composition of the preparation_pva
# onehot_core composition of the preparation_peg-pcl
# onehot_core composition of the preparation_dspe
# onehot_core composition of the preparation_haucl4
# onehot_core composition of the preparation_cucl2
# onehot_core composition of the preparation_sio2
# onehot_core composition of the preparation_catechin hydrate
# onehot_core composition of the preparation_ps
# onehot_core composition of the preparation_dmpc
# onehot_core composition of the preparation_cetyl palmitate
# onehot_core composition of the preparation_nicotinamide
# onehot_core composition of the preparation_phospholpon 90g
# onehot_core composition of the preparation_male-peg-pla
# onehot_core composition of the preparation_peg-pamam
# onehot_core composition of the preparation_labrasol
# onehot_core composition of the preparation_cholestrol
# onehot_core composition of the preparation_tristearin
# onehot_core composition of the preparation_pla
# onehot_core composition of the preparation_n-butyl-cyanoacrylate
# onehot_core composition of the preparation_mal-peg-pla
# onehot_core composition of the preparation_lecithin
# onehot_core composition of the preparation_ir-775chloride(ir)
# onehot_core composition of the preparation_nppe
# onehot_core composition of the preparation_mc-peg3400-dspe
# onehot_core composition of the preparation_lipoid s75
# onehot_core composition of the preparation_fluorescent carboxylated-polystyrene
# onehot_core composition of the preparation_glycerol
# onehot_core composition of the preparation_plga-peg
# onehot_core composition of the preparation_glycerol monostearate
# onehot_core composition of the preparation_sodium stearate
# onehot_core composition of the preparation_pva9000
# onehot_core composition of the preparation_none
# onehot_core composition of the preparation_others
# onehot_type of targeting ligand_antibody
# onehot_type of targeting ligand_aptamer
# onehot_type of targeting ligand_cell-penetrating peptide
# onehot_type of targeting ligand_cell-penetrating peptide+transferrin
# onehot_type of targeting ligand_folic acid
# onehot_type of targeting ligand_glycosol
# onehot_type of targeting ligand_non-antibody protein
# onehot_type of targeting ligand_none
# onehot_type of targeting ligand_others
# onehot_type of targeting ligand_peptide
# onehot_type of targeting ligand_peptide and others
# onehot_targeting ligand_ lactoferrin
# onehot_targeting ligand_ n-acetyl pro–gly–pro (pgp)
# onehot_targeting ligand_ pep-1 (cgemgwvrc)
# onehot_targeting ligand_ r9f2
# onehot_targeting ligand_ r9f2+transferrin
# onehot_targeting ligand_ rabies virus glycoprotein (rvg) derivative
# onehot_targeting ligand_ tgn peptide (tgnykalhphng)
# onehot_targeting ligand_(tat)glyarglyslysargargglnargarg- argcysgly
# onehot_targeting ligand_15-amino acid peptide gyrpvhnirghwapg (gyr peptide)
# onehot_targeting ligand_8d3
# onehot_targeting ligand_a dual receptor recognizing cell penetrating peptiderrrrrrrrdgr (r8dgr, lower case letter representsd-amino acid residue)
# onehot_targeting ligand_acetylcholine,choline
# onehot_targeting ligand_acid-cleavable folic and kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_adenosine-based agonists
# onehot_targeting ligand_adipose-derived stem cells
# onehot_targeting ligand_amyloid beta
# onehot_targeting ligand_amyloid precursor protein
# onehot_targeting ligand_angiopep-2
# onehot_targeting ligand_angiopep-2
#
# onehot_targeting ligand_angiopep-2 (ang, tffyggsrgkrnnfkteey
# onehot_targeting ligand_angiopep-2 (tffyggsrgkrnnfkteeyc)
# onehot_targeting ligand_angiopep-2(tffyggsrgkrnnfkteeyc)
# onehot_targeting ligand_anti-nestin antibody
# onehot_targeting ligand_anti-nestin antibody，transferrin antibody
# onehot_targeting ligand_anti-pdgfrβ aptamer
# onehot_targeting ligand_anti-pirb antibody
# onehot_targeting ligand_anti-tfra
# onehot_targeting ligand_anti-tfra/bace1
# onehot_targeting ligand_anti-tfrd
# onehot_targeting ligand_anti-transferrin receptor antibody (8d3)-pegdspe
# onehot_targeting ligand_anti-vcam-1 antibody
# onehot_targeting ligand_ap1
# onehot_targeting ligand_apoe mimetic peptide
# onehot_targeting ligand_apolipopretoein e
# onehot_targeting ligand_aprotinin
# onehot_targeting ligand_arg-ala-asp (rad)
# onehot_targeting ligand_arg-gly-asp (rgd)
# onehot_targeting ligand_arg-gly-asp (rgd)+il-13
# onehot_targeting ligand_arginine–glycine–aspartic acid (rgd)
# onehot_targeting ligand_ascorbic acid
# onehot_targeting ligand_asn-gly-arg (ngr)
# onehot_targeting ligand_atwlppr
# onehot_targeting ligand_b6
# onehot_targeting ligand_b6+mazindol
# onehot_targeting ligand_bevacizumab
# onehot_targeting ligand_biotin
# onehot_targeting ligand_bombesin peptide (gqwavghlm)
# onehot_targeting ligand_borneol
# onehot_targeting ligand_bovine lf
# onehot_targeting ligand_c*nnskshtc*
# onehot_targeting ligand_cd 47
# onehot_targeting ligand_cdx peptide
# onehot_targeting ligand_cell-penetrating peptide tat
# onehot_targeting ligand_cereport (rmp-7)-pegdspe
# onehot_targeting ligand_cgcrk
# onehot_targeting ligand_cgkrk
# onehot_targeting ligand_cgkrk &  pep-1 (cgemgwvrc)
# onehot_targeting ligand_cgkrkgygatwllppr
# onehot_targeting ligand_chlorotoxin
# onehot_targeting ligand_cholera toxin b subunit
# onehot_targeting ligand_chondroitin sulfate
# onehot_targeting ligand_clpffd
# onehot_targeting ligand_cngr(cngrcg)
# onehot_targeting ligand_cpps-tat
# onehot_targeting ligand_creka
# onehot_targeting ligand_crgd
# onehot_targeting ligand_crgd(arg-gly-asp)
# onehot_targeting ligand_csspiqgswtwengk(c)wtwgiirleq
# onehot_targeting ligand_cvsrrrrrrggrrrr
# onehot_targeting ligand_cylic rgd
# onehot_targeting ligand_d cdx(greirtgraerwsekf)
# onehot_targeting ligand_d-ae
# onehot_targeting ligand_da7r (drdpdpdldwdtda)
# onehot_targeting ligand_dangiopep
# onehot_targeting ligand_dc(lyp-1)(cgnkrtrgc)
# onehot_targeting ligand_dc(lyp-1)+d cdx
# onehot_targeting ligand_dcdx, the retro–inverso isomer oflcdx,
# onehot_targeting ligand_dehydroascorbic acid
# onehot_targeting ligand_dspe-peg-rvg29 peptide
# onehot_targeting ligand_dspe-peg-triphenylphosphine (tpp)
# onehot_targeting ligand_dspe-peg-triphenylphosphine (tpp)+dspe-peg-rvg29 peptide
# onehot_targeting ligand_dspepeg-mannose
# onehot_targeting ligand_dspepeg-mannose/dspepeg-transferrin
# onehot_targeting ligand_dspepeg-transferrin
# onehot_targeting ligand_dvs (vswfsrhryspfavs)
# onehot_targeting ligand_edb-targeted peptide apt
# onehot_targeting ligand_egfp-egf1 (a protein derived from factor vii )
# onehot_targeting ligand_egfr-targeting peptide (yhwygytpqnvi)
# onehot_targeting ligand_fhk(fhkhkspalspv)
# onehot_targeting ligand_fibrin-binding peptide (creka)
# onehot_targeting ligand_folic
# onehot_targeting ligand_folic acid
# onehot_targeting ligand_folic acid (fa)
# onehot_targeting ligand_folic and kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_fucose
# derivative (l-type)
# onehot_targeting ligand_fucose
# derivative (r-type)
# onehot_targeting ligand_galactose derivative
# onehot_targeting ligand_glucose
# onehot_targeting ligand_glutathione
# onehot_targeting ligand_glutathione
# onehot_targeting ligand_gly-arg-lys-lys-arg-arg-gln-arg-arg-arg- gly (tat)
# onehot_targeting ligand_gly-l- phe-d-thr-gly-l-phe-l-leu-l-ser(o-β-d-glucose)- conh2.
# onehot_targeting ligand_h-thr(bzl)-phe-phe-tyr(br-z)-gly-gly-ser(bzl)-arg(tos)-gly-lys(cl-z)-arg(tos)-asn(xan)-asn(xan)-phe-lys(cl-z)-thr(bzl)-glu(ochex)-glu(ochex)-tyr(br-z)-cys(pmebzl)-oh
# onehot_targeting ligand_h2n-gly- l-phe-d-thr-gly-l-phe-l-leu-l-ser[o-b-d- glucose]-conh2; g7
# onehot_targeting ligand_her2 antibody
# onehot_targeting ligand_hiv-1 trans-activating protein (tat)
# onehot_targeting ligand_hiv-1 trans-activating protein (tat) and transferrin
# onehot_targeting ligand_i6p7
# onehot_targeting ligand_i6p7scr
# onehot_targeting ligand_igg2a-dspe-peg
# onehot_targeting ligand_igg4.1
# onehot_targeting ligand_il-13
# onehot_targeting ligand_il-13
# peptide
# onehot_targeting ligand_ingr(crngrgpdc)
# onehot_targeting ligand_insulin
# onehot_targeting ligand_integrin antagonist
# onehot_targeting ligand_internalizing tumor-penetrating peptide, irgd
# onehot_targeting ligand_irgd
# onehot_targeting ligand_irgd (ccrgdkgpdc)
# onehot_targeting ligand_irgd and tgn
# onehot_targeting ligand_isotye igg
# onehot_targeting ligand_item4 antibody
# onehot_targeting ligand_kikkvkkkgrkkikkvkkkgrk-cys, dnp2-cys
# onehot_targeting ligand_l- disulfide system- glucose
# onehot_targeting ligand_l-ae
# onehot_targeting ligand_l-carnitine
# onehot_targeting ligand_lactoferrin
# onehot_targeting ligand_lactoferrin (lf)
# onehot_targeting ligand_lactofferin
# onehot_targeting ligand_langiopep
# onehot_targeting ligand_lc(lyp-1)(cgnkrtrgc)
# onehot_targeting ligand_lc(lyp-1)+d cdx
# onehot_targeting ligand_lcdx (fkeswreargtrierg)
# onehot_targeting ligand_lmwp
# onehot_targeting ligand_lvs (vswfsrhryspfavs)
# onehot_targeting ligand_maltobionic acid
# onehot_targeting ligand_mannose
# onehot_targeting ligand_mannose derivative
# onehot_targeting ligand_mastoparan
# onehot_targeting ligand_mmp-2-responsive peptides
# onehot_targeting ligand_monosialoganglioside
# onehot_targeting ligand_myristic acid (mc)
# onehot_targeting ligand_myristic acid-drdpdpdldwdtda, mc-da7r
# onehot_targeting ligand_n-acetyl pro-gly-pro
# onehot_targeting ligand_n-palmitoylglucosamine (npg)
# onehot_targeting ligand_nh2-gly-l-phe-d-thr-gly-l-phe-l-leu-l-ser(o-β-d-glucose)-cooh
# onehot_targeting ligand_nic-1
# onehot_targeting ligand_nic-2
# onehot_targeting ligand_none
# onehot_targeting ligand_octa-arginine (r8)
# onehot_targeting ligand_others
# onehot_targeting ligand_ox 26
# onehot_targeting ligand_ox26
# onehot_targeting ligand_ox26 and fab'
# onehot_targeting ligand_ox26-dspe-peg
# onehot_targeting ligand_p-amino-phenyl-a-d-mannopyranoside
# onehot_targeting ligand_p-aminophenyl-α-d-mannopyranoside
# onehot_targeting ligand_penetratin
# onehot_targeting ligand_penetrating peptide, rgd
# onehot_targeting ligand_pep-1 (cgemgwvrc) peptide
# onehot_targeting ligand_pep-1 peptide
# onehot_targeting ligand_pep-1 peptide；borneol(bor)
# onehot_targeting ligand_pep-1(cgemgwvrc)
# onehot_targeting ligand_pep-22
# onehot_targeting ligand_peptide-22 (nh2-c6-[cmprlrgc]c-nh2)
# onehot_targeting ligand_phenylalanine
# onehot_targeting ligand_phosphatidic acid (pa)
# onehot_targeting ligand_phosphatidylserine (ps)
# onehot_targeting ligand_pla
# onehot_targeting ligand_qlpvm
# onehot_targeting ligand_r6dgr
# onehot_targeting ligand_r8-rgd
# onehot_targeting ligand_r9f2
# onehot_targeting ligand_rabies virus glycoprotein-derived peptide
# onehot_targeting ligand_rgd
# onehot_targeting ligand_rgd-k
# onehot_targeting ligand_rgdk
# onehot_targeting ligand_rgdyk
# onehot_targeting ligand_rge(rgerppr)
# onehot_targeting ligand_rgek
# onehot_targeting ligand_ri-ae
# onehot_targeting ligand_ri7217.1.4
# onehot_targeting ligand_rmp-7
# onehot_targeting ligand_rqikiwfqnrrmkwkk
# onehot_targeting ligand_rvg
# onehot_targeting ligand_rvg29
# onehot_targeting ligand_rvg29 (twmpenprpgtpcdiftnsrgkrasnggggggc)
# onehot_targeting ligand_rvg29-biotin peptide (sequence: n term-ytiwmpenprpgtpcdiftnsrgkrasng-
# c2-biotin)
# onehot_targeting ligand_rvg29-cyspeptide
# onehot_targeting ligand_scrambled peptide (hwpyahpthpsw)
# onehot_targeting ligand_serine–arginine–leucine
# onehot_targeting ligand_solanum
# tuberosum lectin
# onehot_targeting ligand_specific peptide against tf receptor
# onehot_targeting ligand_srgd
# onehot_targeting ligand_stapled rgd
# onehot_targeting ligand_stearyl cyclic sls derivative (sls-str peptide)
# onehot_targeting ligand_sulfatide
# onehot_targeting ligand_t12
# (thrppmwspvwp) and mannose
# onehot_targeting ligand_t7 (haiyprh) peptide
# onehot_targeting ligand_t7 (haiyprh) peptide, tat (aygrkkrrqrrr) peptide
# onehot_targeting ligand_t7 序列： chaiyprh
# onehot_targeting ligand_tandem peptide of rgd and octarginine
# onehot_targeting ligand_tat
# onehot_targeting ligand_tat (aygrkkrrqrrr) peptide
# onehot_targeting ligand_tat-biotin peptide (sequence: biotin-ygrkkrrqrrr)
# onehot_targeting ligand_tat-peptide :tyr-gly-arg- (lys)2-(arg)2-gln-(arg)3
# onehot_targeting ligand_tgnykalhphngc
# onehot_targeting ligand_tgnykalhphngc, qshyrhispaqvc
# onehot_targeting ligand_thrppmwspvwp
# onehot_targeting ligand_tlyp-1
# onehot_targeting ligand_tlyp-1 and fhk
# onehot_targeting ligand_transferrin
# onehot_targeting ligand_transferrin (169 peptides)
# onehot_targeting ligand_transferrin (230 peptides)
# onehot_targeting ligand_transferrin (tf)
# onehot_targeting ligand_transferrin and penetratin
# onehot_targeting ligand_transferrin receptor (tfr) aptamer
# onehot_targeting ligand_transferrin+folic acid
# onehot_targeting ligand_transferrin-stearylamine
# onehot_targeting ligand_tumor-homing peptide creka
# onehot_targeting ligand_wga
# onehot_targeting ligand_wheat germ agglutinin
# onehot_targeting ligand_{succinyl[methoxy(polyethylene glycol)2000]} (peg2000-cer16) (cer-peg)
# onehot_targeting ligand_ glucose-peg1000-ch
# onehot_targeting ligand_ glucose-peg200-ch
# onehot_targeting ligand_ glucose-peg2000-ch
# onehot_targeting ligand_ glucose-peg400-ch
# onehot_targeting ligand_β-hydroxybutyric acid
# onehot_targeting ligand_细胞穿透肽tat (aygrkkrrqrrr)
# onehot_targeting ligand_细胞穿透肽tat (aygrkkrrqrrr)-peg-ch
# onehot_targeting ligand_血小板-内皮细胞黏附分子抗体
# onehot_animal model_alzheimer's disease
# onehot_animal model_brain tumor
# onehot_animal model_encephalomyelitis
# onehot_animal model_ischemic stroke
# onehot_animal model_normal
# onehot_animal model_others
# onehot_animal model_parkinson's disease
# onehot_animal model_stroke(ischemic stroke, hemorrhagic stroke)
# onehot_administration route_carotid artery injection
# onehot_administration route_convention-enhanced delivery (ced)
# onehot_administration route_i.n.
# onehot_administration route_i.p.
# onehot_administration route_i.t.
# onehot_administration route_i.v.
# onehot_administration route_none
# onehot_administration route_p.o.
# onehot_administration route_s.c.
# onehot_administration route_through carotid artery
# onehot_administration route_颈动脉注射

# %%
tmp = pd.DataFrame(all_features)[ratio_train2.columns[:-4]]

# %%
import lightgbm as lgb
models = [lgb.Booster(model_file= f'./output/{ratio_oof_path2}/fold%s.ckpt'%i) for i in range(10)]

# %% [markdown]
# # Predict ratio of preparation/free drug

# %%
10**np.mean([m.predict(tmp) for m in models],axis=0)
# Out:
# array([4.14648283, 6.11219813, 5.63301324, 5.79380783, 5.05133371,
#        4.56408865])
